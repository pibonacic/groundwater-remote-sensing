# %%
import pandas as pd
from v2_preparation import load_and_prepare_data, slice_by_dates

# %%
cr2met = load_and_prepare_data(
    filepath='../data/camels_cl_1050004/precip_cr2met_mon.csv',
    index_col='date'
    )
cr2met = slice_by_dates(
    cr2met,
    startDate='1995',
    endDate='2020'
)
cr2met= cr2met['1050004']

# %%
# # pp
# import matplotlib.pyplot as plt

# cr2met = load_and_prepare_data(
#     filepath='../data/camels_cl_1050004/precip_cr2met_mon.csv',
#     index_col='date'
#     )
# cr2met = slice_by_dates(
#     cr2met,
#     startDate='1995',
#     endDate='2020'
# )
# cr2met= cr2met['1050004']
# print(cr2met.head())

# fig, ax1 = plt.subplots(figsize=(18, 6))

# ax1.plot(predictions_2000_2026.index, predictions_2000_2026['Predicted'], label='Model predictions', color='#C44E52', linewidth=1.5, linestyle='--')
# ax2 = ax1.twinx()
# ax2.bar(cr2met.index, cr2met, label='precpitation', alpha=1, color='blue', width=30)

# ax1.set_ylabel('Groundwater depth (m)')
# ax1.legend(loc='upper left')

# plt.tight_layout()
plt.show()
# Out:
# <Axes: xlabel='date'>
